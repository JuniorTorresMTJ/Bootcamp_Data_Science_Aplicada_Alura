# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorTorresMTJ/Bootcamp_Data_Science_Aplicada_Alura/blob/main/notebook/An%C3%A1lise_e_Previs%C3%A3o_de_S%C3%A9ries_Temporais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
url = 'https://github.com/JuniorTorresMTJ/Bootcamp_Data_Science_Aplicada_Alura/blob/main/dados/Modulo3/dados_covid_sp.zip?raw=true'

# %%
dados = pd.read_csv(url, sep=';', compression='zip')
dados.head()
# Out:
#          nome_munic  codigo_ibge  dia  ...  latitude longitude  semana_epidem
# 0        Adamantina      3500105   25  ...  -21,6820  -51,0737              9
# 1            Adolfo      3500204   25  ...  -21,2325  -49,6451              9
# 2             Aguaí      3500303   25  ...  -22,0572  -46,9735              9
# 3    Águas da Prata      3500402   25  ...  -21,9319  -46,7176              9
# 4  Águas de Lindóia      3500501   25  ...  -22,4733  -46,6314              9
#
# [5 rows x 26 columns]

# %%
dados['datahora'] = pd.to_datetime(dados['datahora'], format = '%Y-%m-%d')

# %%
mpl.rcParams['font.size'] = 18
mpl.rcParams['figure.figsize'] = (12,8)

# %%
sns.lineplot(x='datahora', y ='casos', data = dados)

# %%
eixo_x = np.linspace(-2,2,100)

# %%
y_exp = np.exp(eixo_x)

# %%
sns.lineplot(x=eixo_x, y=y_exp)

# %%
sns.lineplot(x=eixo_x, y=y_exp)
mpl.pyplot.yscale('log')

# %%
dados_sp = dados.query('nome_munic == "São Paulo"')

# %%
sns.lineplot(x ='datahora', y='casos', data=dados_sp)
mpl.pyplot.yscale('log')
